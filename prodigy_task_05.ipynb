# %%
import pandas as pd
df = pd.read_csv('/content/RTA Dataset.csv')
df
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17:02:00      Monday              18-30          Male
# 1     17:02:00      Monday              31-50          Male
# 2     17:02:00      Monday              18-30          Male
# 3      1:06:00      Sunday              18-30          Male
# 4      1:06:00      Sunday              18-30          Male
# ...        ...         ...                ...           ...
# 5988  15:34:00      Monday              31-50          Male
# 5989   8:46:00   Wednesday            Unknown          Male
# 5990  16:59:00    Saturday            Over 51          Male
# 5991  21:30:00      Monday           Under 18          Male
# 5992  21:30:00      Monday            Under 1           NaN
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 0      Above high school                Employee              1-2yr
# 1     Junior high school                Employee         Above 10yr
# ...

# %%
print(df.isnull().sum())
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     1
# Educational_level               350
# Vehicle_driver_relation         247
# Driving_experience              398
# Type_of_vehicle                 482
# Owner_of_vehicle                231
# Service_year_of_vehicle        1974
# Defect_of_vehicle              2202
# Area_accident_occured           119
# Lanes_or_Medians                200
# Road_allignment                  68
# Types_of_Junction                 1
# Road_surface_type                82
# Road_surface_conditions           1
# Light_conditions                  1
# Weather_conditions                1
# Type_of_collision                66
# Number_of_vehicles_involved       1
# Number_of_casualties              1
# Vehicle_movement                123
# Casualty_class                    1
# Sex_of_casualty                   1
# Age_band_of_casualty              1
# ...

# %%
df1 = df.fillna(df.mode().iloc[0])
df1
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     17:02:00      Monday              18-30          Male
# 1     17:02:00      Monday              31-50          Male
# 2     17:02:00      Monday              18-30          Male
# 3      1:06:00      Sunday              18-30          Male
# 4      1:06:00      Sunday              18-30          Male
# ...        ...         ...                ...           ...
# 5988  15:34:00      Monday              31-50          Male
# 5989   8:46:00   Wednesday            Unknown          Male
# 5990  16:59:00    Saturday            Over 51          Male
# 5991  21:30:00      Monday           Under 18          Male
# 5992  21:30:00      Monday            Under 1          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 0      Above high school                Employee              1-2yr
# 1     Junior high school                Employee         Above 10yr
# ...

# %%
# Print column names to check for available columns
print(df.columns)

# Extract relevant columns for analysis
relevant_columns = ['Time', 'Day_of_week', 'Weather_conditions', 'Road_surface_conditions']
df_subset = df[relevant_columns]
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
# Print column names of df_subset
print(df_subset.columns)

# Extract relevant columns for analysis
relevant_columns = ['Time', 'Day_of_week', 'Weather_conditions', 'Road_surface_conditions']
df_subset = df[relevant_columns]


# Count accidents by road conditions
road_condition_counts = df_subset['Road_surface_conditions'].value_counts()
# Out:
# Index(['Time', 'Day_of_week', 'Weather_conditions', 'Road_surface_conditions'], dtype='object')

# %%
import matplotlib.pyplot as plt
# Visualize accident hotspots and contributing factors
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
road_condition_counts.plot(kind='bar', color='skyblue')
plt.title('Accidents by Road Conditions')
plt.xlabel('Road Conditions')
plt.ylabel('Number of Accidents')
# Out:
# Text(0, 0.5, 'Number of Accidents')

# %%
weather_counts = df_subset['Weather_conditions'].value_counts()

# Count accidents by time of the day
time_of_day_counts = df_subset['Time'].apply(lambda x: x.split(':')[0]).value_counts()

# Visualize accident hotspots and contributing factors
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
road_condition_counts.plot(kind='bar', color='skyblue')
plt.title('Accidents by Road Conditions')
plt.xlabel('Road Conditions')
plt.ylabel('Number of Accidents')
# Out:
# Text(0, 0.5, 'Number of Accidents')

# %%
time_of_day_counts = df_subset['Time'].apply(lambda x: x.split(':')[0]).value_counts()

# Visualize accident hotspots and contributing factors
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
road_condition_counts.plot(kind='bar', color='skyblue')
plt.title('Accidents by Road Conditions')
plt.xlabel('Road Conditions')
plt.ylabel('Number of Accidents')

plt.subplot(1, 3, 2)
weather_counts.plot(kind='bar', color='lightgreen')
plt.title('Accidents by Weather')
plt.xlabel('Weather')
plt.ylabel('Number of Accidents')

plt.subplot(1, 3, 3)
time_of_day_counts.sort_index().plot(kind='bar', color='salmon')
plt.title('Accidents by Time of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Accidents')

plt.tight_layout()
plt.show()
